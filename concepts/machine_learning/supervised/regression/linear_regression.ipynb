# %% [markdown]
# # Linear Regression
# We compute the *linear relationship* between the dependent variable and one or more independent features by fitting a **linear equation** with observed data.

# %% [markdown]
# > For example if we want to predict house price we consider various factor such as house age, distance from the main road, location, area and number of room, linear regression uses all these parameter to predict house price as it consider a linear relation between all these features and price of house.

# %% [markdown]
# ### Best Fit Line
# The best Fit Line equation provides a straight line that represents the relationship between the dependent and independent variables. The slope of the line indicates how much the dependent variable changes for a unit change in the independent variable(s).
#
# ![image.png](attachment:image.png)
#
# Here Y is a dependent variable and X is the independant variable. X may be a single feature or consist of different feature.

# %%
from sklearn import linear_model

reg = linear_model.LinearRegression()
reg.fit([[0, 0], [1, 1], [2, 2]], [0, 1, 2])
reg.coef_
# Out:
# array([0.5, 0.5])

# %% [markdown]
# The coefficient estimates for **Ordinary Least Squares** rely on the independence of the features.
# This is a type of linear least squares method for choosing the unknown parameters in a linear regression model
